# %%
import pandas as pd
from math import*
import re
import logging
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import PCA, TruncatedSVD
import seaborn as sns
import nltk
from nltk.stem.snowball import SnowballStemmer
from nltk.corpus import stopwords
from sklearn.metrics.pairwise import cosine_similarity

# %%
#initialisation
n_most_similar = 1
n_features_title = 25
n_features_content = 50
n_features_tags = 25
n_features_total = 30


df = None #dataframe
df_article_vectors = None #vectorized articles
similarity_score_dict = {} #similarity score dictionary for articles
X = None
X_title = None  #vectorized title
X_content = None  #vectorized content
X_tags = None #vectorized tags

# %% [markdown]
# # DATA LOADING + CLEANING

# %%
# load data
df = pd.read_csv('/home/pallavi/SEM_5/DA/PROJECT/dataset/articles.csv', encoding='utf-8') # Load articles in a DataFrame
df = df[['title', 'content_text', 'tags']]  # Slice to remove redundant columns
df.head()
len(df)
# Out:
# 186

# %%
# assigning tags to each article
temp = df['tags']      
temp = temp.str.lower()
temp = temp.str.split(",", n = 1, expand = True)
temp = temp[0]
temp = temp.str.replace("[","")
temp = temp.str.replace("]","")
temp = temp.str.replace("'","")
df['first_tag'] = temp
df

for i in range(0, len(df["first_tag"])):
    if df["first_tag"][i] == '':
        df["first_tag"][i] = 'none'
df["first_tag"]
# Out:
# 0                             none
# 1                augmented reality
# 2                       javascript
# 3                         snapchat
# 4                         facebook
# 5                augmented reality
# 6                     data science
# 7                 google analytics
# 8                             tech
# 9               google tag manager
# 10                       analytics
# 11                       analytics
# 12                       analytics
# 13     consumer friendly marketing
# 14                       analytics
# 15                            code
# 16                       analytics
# 17                    data science
# 18                         adwords
# 19                            none
# 20                             cro
# 21                            none
# 22                            code
# 23                            none
# 24                       analytics
# 25                            code
# 26                            none
# 27                       analytics
# 28                            none
# 29                       analytics
#                   ...
# 156                           code
# 157                         events
# 158                         mobile
# 159                      analytics
# 160                           code
# 161                           code
# 162                      marketing
# 163                           code
# 164                           code
# 165                           code
# 166                           code
# 167                      marketing
# 168                   data science
# 169                           code
# 170                      marketing
# 171                      analytics
# 172                           code
# 173                   data science
# 174                       ghostery
# 175                     optimizely
# 176                            cro
# 177                   data science
# 178                      angularjs
# 179                            cro
# 180               google analytics
# 181                       thoughts
# 182                        testing
# 183                      analytics
# 184                          html5
# 185                   introduction
# Name: first_tag, Length: 186, dtype: object

# %%
# split into train and test
train=df[:180]
test = df[180:]

# %% [markdown]
# # CONVERTING ARTICLES TO NUMERIC FORMAT

# %% [markdown]
# vectorize data
#
# Vectorize training data, i.e. perform a 3-gram feature extraction and selection method using FP, Chi or RP
#
# return: Result is a numeric and weighted feature vector notation for each article

# %%
def vectorize_articles():
        global X
        # Vectorize article
        vectorize_title()    # Add title as dummies
        vectorize_content()  # Add content as dummies
        vectorize_tags()     # Add title as dummies
       #Concatenate all article vectors, i.e. title, content, tags and author
        article_metrics = (X_title, X_content, X_tags)
        X = np.concatenate(article_metrics, axis=1)

# %%
# vectorizer function : uses the concept of BOW(bag of words) along with n-gram(to preserve some ordering) 
def get_vectorizer(ngram_range=(1, 3), min_df=2, max_df=1.0):
    
        vectorizer = CountVectorizer(ngram_range=ngram_range,
                                     tokenizer=tokenize,
                                     min_df=min_df,
                                     max_df=max_df,
                                     binary=True,
                                     stop_words='english')
        return vectorizer

# %%
# tokenization function to be passed as the tokenizer to the CountVectorizer function
# removes white spaces, stop words and stems the document
def tokenize(text):
    tokens = nltk.WhitespaceTokenizer().tokenize(text)
    tokens = list(set(re.sub("[^a-zA-Z\']", "", token) for token in tokens))
    tokens = [word for word in tokens if word not in stopwords.words('english')]
    tokens = list(set(re.sub("[^a-zA-Z]", "", token) for token in tokens))
    stems = []
    stemmer = SnowballStemmer("english")
    for token in tokens:
        token = stemmer.stem(token)
        if token != "":
            stems.append(token)
    return stems

# %%
# vectorize title
def vectorize_title():
    global X_title
    vectorizer = get_vectorizer(ngram_range=(1, 2),min_df=2)
    X_title = vectorizer.fit_transform(train['title'])
    X_title = X_title.toarray()
    X_title = np.array(X_title, dtype=float)
    X_title = reduce_dimensionality(X_title, n_features=n_features_title)

# %%
# vectorize content
def vectorize_content():
    global X_content
    vectorizer = get_vectorizer(ngram_range=(1, 1),min_df=4,max_df=0.3)
    X_content = vectorizer.fit_transform(train['content_text'])
    X_content = X_content.toarray()
    X_content = np.array(X_content, dtype=float)
    X_content = reduce_dimensionality(X_content, n_features=n_features_content)

# %%
# vectorize tags
def vectorize_tags():
    global X_tags
    n_tags = 0
    df_tags = pd.DataFrame(index=train.index)
    # df_tags
    df_tags.columns
    for index, row in train.iterrows():
            if row['tags'] != '':
                values = row['tags'].split(", ")
                for value in values:
                    if value not in df_tags.columns:
                        df_tags[value] = 0.0
                        n_tags += 1
                    df_tags.ix[index, value] = 1.0
    X_tags = np.array(df_tags, dtype=float)
    X_tags = reduce_dimensionality(X_tags, n_features=n_features_tags)
    
# df_tags

# %%
# Reduce the dimensionality of the vectorized articles.
def reduce_dimensionality_articles():
        global X
        X = reduce_dimensionality(X, n_features=n_features_total)

# %%
# Apply PCA or SVD to reduce dimension to n_features.
def reduce_dimensionality(X, n_features):
        # Initialize reduction method: PCA or SVD
        # reducer = PCA(n_components=n_features)
        reducer = TruncatedSVD(n_components=n_features)
        # Fit and transform data to n_features-dimensional space
        reducer.fit(X)
        X = reducer.transform(X)
        return X

# %%
vectorize_articles()
reduce_dimensionality_articles()
# Out:
# /usr/local/lib/python3.5/dist-packages/sklearn/feature_extraction/text.py:286: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['afterward', 'alon', 'alreadi', 'alway', 'anoth', 'anyon', 'anyth', 'anywher', 'becam', 'becom', 'besid', 'cri', 'describ', 'els', 'elsewher', 'empti', 'everi', 'everyon', 'everyth', 'everywher', 'fifti', 'forti', 'henc', 'hereaft', 'herebi', 'howev', 'hundr', 'inde', 'mani', 'meanwhil', 'moreov', 'nobodi', 'noon', 'noth', 'nowher', 'otherwis', 'perhap', 'pleas', 'sever', 'sinc', 'sincer', 'sixti', 'someon', 'someth', 'sometim', 'somewher', 'thenc', 'thereaft', 'therebi', 'therefor', 'togeth', 'twelv', 'twenti', 'whatev', 'whenc', 'whenev', 'wherea', 'whereaft', 'wherebi', 'wherev'] not in stop_words.
#   sorted(inconsistent))
# /usr/local/lib/python3.5/dist-packages/sklearn/feature_extraction/text.py:286: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['afterward', 'alon', 'alreadi', 'alway', 'anoth', 'anyon', 'anyth', 'anywher', 'becam', 'becom', 'besid', 'cri', 'describ', 'els', 'elsewher', 'empti', 'everi', 'everyon', 'everyth', 'everywher', 'fifti', 'forti', 'henc', 'hereaft', 'herebi', 'howev', 'hundr', 'inde', 'mani', 'meanwhil', 'moreov', 'nobodi', 'noon', 'noth', 'nowher', 'otherwis', 'perhap', 'pleas', 'sever', 'sinc', 'sincer', 'sixti', 'someon', 'someth', 'sometim', 'somewher', 'thenc', 'thereaft', 'therebi', 'therefor', 'togeth', 'twelv', 'twenti', 'whatev', 'whenc', 'whenev', 'wherea', 'whereaft', 'wherebi', 'wherev'] not in stop_words.
#   sorted(inconsistent))
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:15: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   from ipykernel import kernelapp as app

# %%
X[0]
# Out:
# array([ 5.27432746, -1.0674006 ,  0.58818573, -0.73515761, -1.48511213,
#         0.99543509, -1.36163126, -1.19678443,  1.66613997,  1.70034146,
#         0.25801295, -1.26855904,  1.02698313,  1.9399505 ,  1.32056582,
#        -0.15493699, -0.51513587,  0.1645276 ,  1.63753212,  0.05485209,
#         1.19771236, -1.02707691, -1.5937034 ,  0.30386856, -0.28150737,
#        -1.75162493,  1.92201944, -1.03360158, -1.02197656,  0.43608158])

# %%
def prepare_dataframe(X):
        global n_most_similar
        df_article_vectors = pd.DataFrame(None)
        df_article_vectors['first_tag'] = train['first_tag']
        df_article_vectors['title'] = train['title']
        df_article_vectors['numbers'] = range(0, len(df_article_vectors))
        df_article_vectors['coordinates'] = df_article_vectors['numbers'].apply(lambda index: X[index, :])
        del df_article_vectors['numbers']
        # Initialize dataframe by appending new columns to store the titles of the n most similar articles
        for i in range(0, n_most_similar):
            df_article_vectors['most_similar_'+str(i+1)] = ""
        return df_article_vectors

# %%
def visualize_data():
        global X
        # Reduce dimensionality to 2 features for visualization purposes
        X_visualization = reduce_dimensionality(X, n_features=2)
        df = prepare_dataframe(X_visualization)
        # Set X and Y coordinate for each articles
        df['X coordinate'] = df['coordinates'].apply(lambda x: x[0])
        df['Y coordinate'] = df['coordinates'].apply(lambda x: x[1])
        # Create a list of markers, each tag has its own marker
        n_tags_first = len(df['first_tag'].unique())
        markers_choice_list = ['o', 's', '^', '.', 'v', '<', '>', 'D']
        markers_list = [markers_choice_list[i % 8] for i in range(n_tags_first)]
        # Create scatter plot
        sns.lmplot("X coordinate",
                   "Y coordinate",
                   hue="first_tag",
                   data=df,
                   fit_reg=False,
                   markers=markers_list,
                   scatter_kws={"s": 150})
        # Adjust borders and add title
        sns.set(font_scale=1)
        sns.plt.title('Visualization of TMT articles in a 2-dimensional space')
        sns.plt.subplots_adjust(right=1, top=1, left=1, bottom=1)
        # Show plot
        sns.plt.show()

# %%
visualize_data()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-c1ea994916de> in <module>
# ----> 1 visualize_data()
#
# <ipython-input-18-4497ca1f0efc> in visualize_data()
#      21         # Adjust borders and add title
#      22         sns.set(font_scale=1)
# ---> 23         sns.plt.title('Visualization of TMT articles in a 2-dimensional space')
#      24         sns.plt.subplots_adjust(right=1, top=1, left=1, bottom=1)
#      25         # Show plot
#
# AttributeError: module 'seaborn' has no attribute 'plt'

# %% [markdown]
# similar articles using cosine similarity

# %%
sim = cosine_similarity(X)
sim[0]
# Out:
# array([1.        , 0.39436136, 0.30209184, 0.3057089 , 0.3139583 ,
#        0.28865497, 0.45042599, 0.45103265, 0.4307042 , 0.52189423,
#        0.60508849, 0.53991113, 0.60714479, 0.4121792 , 0.54390858,
#        0.33655386, 0.7427255 , 0.6079505 , 0.56110142, 0.45530311,
#        0.35439256, 0.40765842, 0.37173171, 0.64166125, 0.56736765,
#        0.35381291, 0.4304742 , 0.52862126, 0.5142528 , 0.6327192 ,
#        0.34975995, 0.50040742, 0.3905478 , 0.36871229, 0.27370231,
#        0.4061419 , 0.52169554, 0.4054079 , 0.46657767, 0.30204377,
#        0.24808159, 0.31626082, 0.43534916, 0.19659789, 0.47400983,
#        0.46655321, 0.50481745, 0.4084533 , 0.37292773, 0.51430501,
#        0.32715784, 0.47097329, 0.29415189, 0.34065992, 0.46845669,
#        0.4814177 , 0.35487651, 0.23008274, 0.53640587, 0.51595   ,
#        0.56815638, 0.4449725 , 0.31531172, 0.24836738, 0.34058708,
#        0.32761731, 0.44242021, 0.45426277, 0.18989695, 0.38383346,
#        0.49587399, 0.42076254, 0.52755034, 0.45718958, 0.28122648,
#        0.43444339, 0.28111038, 0.46251396, 0.36246727, 0.41848229,
#        0.43093065, 0.26502512, 0.52258506, 0.41094589, 0.45339593,
#        0.18007903, 0.38862658, 0.36356445, 0.3621655 , 0.26162885,
#        0.45008443, 0.26092264, 0.37860732, 0.31790072, 0.466628  ,
#        0.41978621, 0.25141775, 0.26628121, 0.25407826, 0.48707446,
#        0.28465713, 0.40601394, 0.41801236, 0.55281133, 0.42980194,
#        0.29317368, 0.31122077, 0.46846968, 0.28900333, 0.42299349,
#        0.31569934, 0.25548734, 0.24294843, 0.40228023, 0.35319329,
#        0.42877203, 0.58449274, 0.29337855, 0.41025543, 0.47243533,
#        0.28732334, 0.11352019, 0.39895992, 0.42231861, 0.31841853,
#        0.33748806, 0.34083847, 0.4069378 , 0.42510018, 0.41834641,
#        0.26424702, 0.34219671, 0.33293778, 0.30281763, 0.44621136,
#        0.52467908, 0.2811572 , 0.56014033, 0.27844155, 0.39864755,
#        0.58678492, 0.17070524, 0.24032443, 0.32470735, 0.4433976 ,
#        0.33897928, 0.54075697, 0.32410089, 0.35824974, 0.60391311,
#        0.39931382, 0.25134652, 0.20187551, 0.32443969, 0.32177426,
#        0.20984977, 0.29698686, 0.29794075, 0.32211492, 0.30583613,
#        0.35516404, 0.54720958, 0.42878349, 0.26058414, 0.40165465,
#        0.19763123, 0.2616482 , 0.29195649, 0.18331887, 0.41608531,
#        0.26118907, 0.48709509, 0.31539991, 0.41978787, 0.52168641,
#        0.32113407, 0.38770325, 0.42578206, 0.26120798, 0.29332367])

# %%
sim_doc = []
docx = 0
docy = 0
temp_sim = []

for x in sim:
    for y in x:
        if y > 0.5 and y:
            temp_sim.append(docy)
        docy = docy+1
    
    sim_doc.append(temp_sim)
    docy = 0
    temp_sim = []
                        
sim_doc
# Out:
# [[0,
#   9,
#   10,
#   11,
#   12,
#   14,
#   16,
#   17,
#   18,
#   23,
#   24,
#   27,
#   28,
#   29,
#   31,
#   36,
#   46,
#   49,
#   58,
#   59,
#   60,
#   72,
#   82,
#   103,
#   116,
#   135,
#   137,
#   140,
#   146,
#   149,
#   161,
#   174],
#  [1, 74, 93, 98],
#  [2, 65, 77, 88, 101, 129, 135, 151, 160, 169, 172, 176, 179],
#  [3, 4, 5, 6, 42, 47, 56, 75, 76, 81, 84, 91, 97, 106, 170],
#  [3, 4, 5, 39, 46, 67, 75, 76, 89, 105, 106, 120, 130],
#  [3,
#   4,
#   6,
#   30,
#   46,
#   56,
#   57,
#   68,
#   74,
#   75,
#   77,
#   78,
#   88,
#   98,
#   101,
#   120,
#   126,
#   145,
#   175,
#   176],
#  [3, 5, 6, 20, 44, 50, 75, 78, 92, 98, 101, 130, 139, 152, 162, 173, 177],
#  [9,
#   10,
#   11,
#   14,
#   18,
#   21,
#   22,
#   24,
#   25,
#   26,
#   27,
#   29,
#   38,
#   51,
#   53,
#   54,
#   55,
#   59,
#   66,
#   70,
#   72,
#   77,
#   79,
#   82,
#   87,
#   88,
#   99,
#   102,
#   104,
#   107,
#   108,
#   109,
#   111,
#   119,
#   125,
#   126,
#   127,
#   131,
#   133,
#   134,
#   136,
#   137,
#   142,
#   143,
#   144,
#   145,
#   146,
#   150,
#   153,
#   154,
#   155,
#   156,
#   163,
#   164,
#   166,
#   174,
#   175,
#   176,
#   178],
#  [8, 46, 65, 99, 101, 107, 123, 135, 149, 151, 160, 172, 179],
#  [0,
#   7,
#   9,
#   10,
#   11,
#   14,
#   18,
#   23,
#   24,
#   25,
#   26,
#   27,
#   29,
#   32,
#   35,
#   38,
#   54,
#   55,
#   59,
#   70,
#   72,
#   79,
#   82,
#   90,
#   99,
#   102,
#   104,
#   108,
#   119,
#   125,
#   128,
#   129,
#   131,
#   133,
#   134,
#   135,
#   136,
#   137,
#   144,
#   145,
#   146,
#   150,
#   160,
#   164,
#   169,
#   174,
#   175,
#   176],
#  [0,
#   7,
#   9,
#   11,
#   14,
#   18,
#   23,
#   25,
#   26,
#   27,
#   29,
#   35,
#   38,
#   51,
#   54,
#   55,
#   61,
#   70,
#   72,
#   79,
#   87,
#   99,
#   102,
#   104,
#   107,
#   108,
#   119,
#   122,
#   123,
#   125,
#   127,
#   133,
#   134,
#   135,
#   136,
#   137,
#   142,
#   144,
#   145,
#   146,
#   150,
#   164,
#   174,
#   175,
#   176],
#  [0,
#   7,
#   9,
#   10,
#   11,
#   14,
#   18,
#   23,
#   25,
#   26,
#   27,
#   29,
#   35,
#   38,
#   48,
#   54,
#   55,
#   61,
#   67,
#   70,
#   71,
#   72,
#   79,
#   82,
#   99,
#   102,
#   108,
#   119,
#   123,
#   125,
#   128,
#   133,
#   134,
#   135,
#   136,
#   137,
#   144,
#   145,
#   146,
#   150,
#   160,
#   164,
#   174,
#   175,
#   176],
#  [0,
#   12,
#   16,
#   20,
#   24,
#   28,
#   29,
#   31,
#   36,
#   37,
#   44,
#   46,
#   48,
#   59,
#   86,
#   94,
#   103,
#   117,
#   118,
#   119,
#   122,
#   140,
#   149,
#   161],
#  [13, 147],
#  [0,
#   7,
#   9,
#   10,
#   11,
#   14,
#   18,
#   22,
#   24,
#   26,
#   27,
#   29,
#   38,
#   51,
#   53,
#   54,
#   55,
#   59,
#   61,
#   66,
#   70,
#   72,
#   77,
#   79,
#   82,
#   87,
#   88,
#   90,
#   92,
#   99,
#   102,
#   104,
#   107,
#   108,
#   109,
#   119,
#   123,
#   125,
#   126,
#   127,
#   129,
#   131,
#   133,
#   134,
#   135,
#   136,
#   137,
#   139,
#   142,
#   143,
#   144,
#   145,
#   146,
#   150,
#   154,
#   156,
#   164,
#   165,
#   166,
#   171,
#   174,
#   175,
#   176,
#   178],
#  [22, 25, 28, 30, 52, 60, 69, 87, 101, 108, 123, 135, 143, 148, 163],
#  [0,
#   12,
#   18,
#   23,
#   24,
#   28,
#   29,
#   31,
#   36,
#   37,
#   46,
#   49,
#   51,
#   58,
#   59,
#   60,
#   66,
#   67,
#   73,
#   82,
#   83,
#   86,
#   90,
#   94,
#   99,
#   103,
#   105,
#   107,
#   113,
#   115,
#   116,
#   117,
#   118,
#   122,
#   132,
#   137,
#   140,
#   147,
#   148,
#   149,
#   161,
#   162],
#  [0, 32, 72, 82, 95, 118, 129],
#  [0,
#   7,
#   9,
#   10,
#   11,
#   14,
#   16,
#   18,
#   23,
#   25,
#   26,
#   27,
#   29,
#   38,
#   54,
#   55,
#   60,
#   61,
#   67,
#   70,
#   71,
#   73,
#   84,
#   90,
#   96,
#   99,
#   102,
#   107,
#   108,
#   111,
#   123,
#   126,
#   127,
#   128,
#   131,
#   133,
#   134,
#   135,
#   136,
#   137,
#   142,
#   143,
#   144,
#   145,
#   146,
#   149,
#   150,
#   153,
#   154,
#   155,
#   160,
#   164,
#   174,
#   175,
#   176],
#  [21, 28, 49, 53, 59, 66, 92, 101, 109, 126, 129, 140, 146],
#  [6,
#   12,
#   31,
#   36,
#   37,
#   43,
#   46,
#   47,
#   48,
#   50,
#   58,
#   68,
#   74,
#   79,
#   80,
#   83,
#   84,
#   86,
#   94,
#   103,
#   118,
#   121,
#   130,
#   147,
#   149,
#   152,
#   157,
#   167],
#  [7,
#   19,
#   21,
#   28,
#   53,
#   59,
#   66,
#   101,
#   109,
#   127,
#   129,
#   143,
#   146,
#   153,
#   154,
#   155,
#   156,
#   166,
#   172,
#   178],
#  [7,
#   14,
#   15,
#   22,
#   25,
#   30,
#   32,
#   33,
#   38,
#   48,
#   52,
#   54,
#   60,
#   69,
#   70,
#   71,
#   77,
#   79,
#   87,
#   88,
#   101,
#   104,
#   108,
#   111,
#   115,
#   123,
#   124,
#   125,
#   127,
#   131,
#   135,
#   136,
#   137,
#   142,
#   143,
#   145,
#   146,
#   151,
#   154,
#   156,
#   160,
#   161,
#   163,
#   164,
#   165,
#   166,
#   171,
#   172,
#   174,
#   175,
#   176,
#   178,
#   179],
#  [0,
#   9,
#   10,
#   11,
#   16,
#   18,
#   24,
#   27,
#   28,
#   29,
#   31,
#   38,
#   48,
#   50,
#   51,
#   59,
#   69,
#   70,
#   71,
#   73,
#   78,
#   80,
#   83,
#   86,
#   90,
#   94,
#   103,
#   108,
#   123,
#   134,
#   135,
#   137,
#   140,
#   146,
#   148,
#   150,
#   164,
#   174],
#  [0,
#   7,
#   9,
#   12,
#   14,
#   16,
#   23,
#   24,
#   26,
#   29,
#   31,
#   36,
#   38,
#   46,
#   51,
#   55,
#   59,
#   66,
#   69,
#   70,
#   72,
#   75,
#   80,
#   82,
#   83,
#   86,
#   90,
#   92,
#   97,
#   99,
#   103,
#   114,
#   119,
#   130,
#   131,
#   132,
#   134,
#   137,
#   138,
#   140,
#   146,
#   153,
#   164,
#   174,
#   176],
#  [7,
#   9,
#   10,
#   11,
#   15,
#   18,
#   22,
#   25,
#   28,
#   30,
#   33,
#   35,
#   52,
#   60,
#   61,
#   69,
#   70,
#   71,
#   72,
#   87,
#   88,
#   104,
#   108,
#   111,
#   113,
#   115,
#   118,
#   125,
#   127,
#   135,
#   136,
#   142,
#   143,
#   145,
#   148,
#   150,
#   151,
#   154,
#   156,
#   161,
#   163,
#   165,
#   166,
#   172,
#   174,
#   176,
#   178,
#   179],
#  [7,
#   9,
#   10,
#   11,
#   14,
#   18,
#   24,
#   27,
#   29,
#   38,
#   51,
#   53,
#   55,
#   57,
#   59,
#   61,
#   66,
#   70,
#   73,
#   79,
#   83,
#   90,
#   92,
#   99,
#   102,
#   109,
#   110,
#   114,
#   119,
#   125,
#   126,
#   128,
#   131,
#   132,
#   133,
#   134,
#   137,
#   138,
#   139,
#   144,
#   146,
#   150,
#   153,
#   164,
#   166,
#   174,
#   175,
#   176],
#  [0,
#   7,
#   9,
#   10,
#   11,
#   14,
#   18,
#   23,
#   26,
#   27,
#   29,
#   38,
#   51,
#   53,
#   54,
#   55,
#   59,
#   61,
#   66,
#   70,
#   73,
#   79,
#   82,
#   84,
#   86,
#   90,
#   92,
#   99,
#   102,
#   107,
#   108,
#   119,
#   123,
#   125,
#   126,
#   127,
#   128,
#   131,
#   133,
#   134,
#   135,
#   136,
#   137,
#   144,
#   145,
#   146,
#   150,
#   153,
#   154,
#   155,
#   160,
#   164,
#   174,
#   175,
#   176],
#  [0,
#   12,
#   15,
#   16,
#   19,
#   21,
#   23,
#   25,
#   28,
#   31,
#   52,
#   59,
#   70,
#   71,
#   78,
#   99,
#   101,
#   103,
#   113,
#   123,
#   137,
#   140,
#   146,
#   148,
#   150,
#   166,
#   172],
#  [0,
#   7,
#   9,
#   10,
#   11,
#   12,
#   14,
#   16,
#   18,
#   23,
#   24,
#   26,
#   27,
#   29,
#   36,
#   38,
#   48,
#   51,
#   54,
#   55,
#   66,
#   67,
#   70,
#   72,
#   79,
#   82,
#   83,
#   84,
#   90,
#   99,
#   102,
#   107,
#   108,
#   119,
#   122,
#   123,
#   125,
#   133,
#   134,
#   137,
#   140,
#   144,
#   146,
#   149,
#   150,
#   164,
#   174,
#   175,
#   176],
#  [5, 15, 22, 25, 30, 52, 69, 77, 88, 101, 108, 123, 135, 148, 174, 179],
#  [0,
#   12,
#   16,
#   20,
#   23,
#   24,
#   28,
#   31,
#   36,
#   37,
#   44,
#   48,
#   50,
#   51,
#   55,
#   56,
#   59,
#   60,
#   69,
#   70,
#   73,
#   80,
#   83,
#   86,
#   90,
#   92,
#   94,
#   97,
#   103,
#   114,
#   121,
#   123,
#   140,
#   147,
#   148,
#   152,
#   167,
#   171],
#  [9,
#   17,
#   22,
#   32,
#   35,
#   45,
#   60,
#   62,
#   65,
#   68,
#   72,
#   82,
#   87,
#   88,
#   95,
#   104,
#   113,
#   122,
#   124,
#   127,
#   128,
#   129,
#   136,
#   139,
#   142,
#   145,
#   151,
#   154,
#   160,
#   165,
#   169,
#   171,
#   172,
#   175,
#   176],
#  [22,
#   25,
#   33,
#   36,
#   46,
#   54,
#   60,
#   69,
#   87,
#   88,
#   101,
#   107,
#   111,
#   115,
#   118,
#   127,
#   130,
#   135,
#   136,
#   142,
#   143,
#   154,
#   155,
#   156,
#   176,
#   178],
#  [56, 105, 152],
#  [9,
#   10,
#   11,
#   25,
#   32,
#   35,
#   36,
#   48,
#   51,
#   60,
#   61,
#   63,
#   65,
#   71,
#   72,
#   82,
#   87,
#   88,
#   108,
#   111,
#   115,
#   118,
#   119,
#   122,
#   124,
#   125,
#   136,
#   142,
#   143,
#   145,
#   154,
#   163,
#   165,
#   172,
#   178],
#  [0,
#   12,
#   16,
#   20,
#   24,
#   29,
#   31,
#   33,
#   35,
#   36,
#   37,
#   39,
#   40,
#   44,
#   46,
#   48,
#   50,
#   51,
#   55,
#   60,
#   66,
#   67,
#   71,
#   80,
#   82,
#   83,
#   84,
#   86,
#   92,
#   94,
#   103,
#   109,
#   117,
#   119,
#   130,
#   140,
#   146,
#   149,
#   153,
#   162,
#   167,
#   176],
#  [12,
#   16,
#   20,
#   31,
#   36,
#   37,
#   43,
#   45,
#   46,
#   47,
#   48,
#   50,
#   54,
#   55,
#   56,
#   66,
#   79,
#   80,
#   81,
#   82,
#   83,
#   86,
#   94,
#   97,
#   104,
#   107,
#   115,
#   119,
#   121,
#   126,
#   135,
#   140,
#   147,
#   148,
#   149,
#   152,
#   167,
#   170,
#   176,
#   179],
#  [7,
#   9,
#   10,
#   11,
#   14,
#   18,
#   22,
#   23,
#   24,
#   26,
#   27,
#   29,
#   38,
#   51,
#   53,
#   55,
#   59,
#   66,
#   70,
#   77,
#   79,
#   80,
#   88,
#   90,
#   92,
#   102,
#   107,
#   108,
#   109,
#   114,
#   119,
#   125,
#   126,
#   128,
#   131,
#   132,
#   133,
#   134,
#   136,
#   137,
#   138,
#   144,
#   146,
#   150,
#   153,
#   155,
#   164,
#   174,
#   175,
#   176],
#  [4, 36, 44, 48, 57, 63, 64, 67, 74, 78, 93, 98, 120, 140, 162],
#  [36, 40, 47, 67, 80, 83, 105, 147, 152, 167, 176],
#  [46, 48, 56, 63, 74, 76, 81, 82, 85, 88, 89, 135, 179],
#  [3, 47, 67, 81, 82, 84, 89, 91, 93, 97, 106, 170, 179],
#  [20, 37, 43, 79],
#  [6, 12, 31, 36, 39, 44, 48, 56, 63, 64, 140, 162],
#  [32, 37, 45, 47, 56, 72, 113, 139, 149, 160],
#  [0,
#   4,
#   5,
#   8,
#   12,
#   16,
#   20,
#   24,
#   33,
#   36,
#   37,
#   41,
#   46,
#   58,
#   60,
#   75,
#   82,
#   88,
#   103,
#   107,
#   115,
#   117,
#   118,
#   130,
#   135,
#   140,
#   149,
#   157,
#   161,
#   162],
#  [3,
#   20,
#   37,
#   40,
#   42,
#   45,
#   47,
#   48,
#   50,
#   76,
#   79,
#   80,
#   81,
#   82,
#   83,
#   84,
#   89,
#   91,
#   104,
#   106,
#   108,
#   112,
#   115,
#   135,
#   140,
#   147,
#   148,
#   149,
#   152,
#   159,
#   162,
#   170,
#   179],
#  [11,
#   12,
#   20,
#   22,
#   23,
#   29,
#   31,
#   35,
#   36,
#   37,
#   39,
#   41,
#   44,
#   47,
#   48,
#   50,
#   63,
#   64,
#   70,
#   79,
#   82,
#   108,
#   121,
#   124,
#   125,
#   134,
#   137,
#   140,
#   146,
#   162,
#   170,
#   179],
#  [0, 16, 19, 49, 60, 92, 110, 114, 116, 128, 132, 138, 153],
#  [6,
#   20,
#   23,
#   31,
#   36,
#   37,
#   47,
#   48,
#   68,
#   73,
#   79,
#   80,
#   81,
#   82,
#   83,
#   84,
#   86,
#   89,
#   92,
#   94,
#   96,
#   106,
#   112,
#   114,
#   121,
#   123,
#   124,
#   135,
#   146,
#   147,
#   148,
#   152,
#   153,
#   159,
#   162,
#   167,
#   170,
#   173,
#   177,
#   179],
#  [7,
#   10,
#   14,
#   16,
#   23,
#   24,
#   26,
#   27,
#   29,
#   31,
#   35,
#   36,
#   38,
#   53,
#   55,
#   59,
#   60,
#   61,
#   66,
#   70,
#   72,
#   73,
#   82,
#   83,
#   84,
#   86,
#   90,
#   92,
#   96,
#   103,
#   106,
#   109,
#   114,
#   117,
#   119,
#   126,
#   130,
#   134,
#   137,
#   140,
#   144,
#   146,
#   150,
#   153,
#   154,
#   164,
#   171,
#   176],
#  [15, 22, 25, 28, 30, 52, 101, 148, 172, 179],
#  [7,
#   14,
#   19,
#   21,
#   26,
#   27,
#   38,
#   51,
#   53,
#   55,
#   59,
#   61,
#   66,
#   73,
#   79,
#   83,
#   86,
#   90,
#   92,
#   94,
#   96,
#   103,
#   109,
#   119,
#   126,
#   137,
#   146,
#   150,
#   153,
#   154,
#   164,
#   173],
#  [7,
#   9,
#   10,
#   11,
#   14,
#   18,
#   22,
#   27,
#   29,
#   33,
#   37,
#   54,
#   56,
#   60,
#   61,
#   67,
#   72,
#   79,
#   102,
#   107,
#   108,
#   111,
#   123,
#   127,
#   128,
#   135,
#   136,
#   139,
#   142,
#   143,
#   145,
#   146,
#   150,
#   154,
#   155,
#   156,
#   160,
#   166,
#   173,
#   174,
#   175,
#   176,
#   178],
#  [7,
#   9,
#   10,
#   11,
#   14,
#   18,
#   24,
#   26,
#   27,
#   29,
#   31,
#   36,
#   37,
#   38,
#   51,
#   53,
#   56,
#   59,
#   60,
#   66,
#   70,
#   73,
#   79,
#   80,
#   82,
#   83,
#   86,
#   90,
#   92,
#   97,
#   99,
#   102,
#   107,
#   114,
#   119,
#   126,
#   128,
#   131,
#   132,
#   133,
#   134,
#   137,
#   138,
#   144,
#   146,
#   147,
#   150,
#   153,
#   164,
#   167,
#   171,
#   174,
#   175,
#   176],
#  [3,
#   5,
#   31,
#   34,
#   37,
#   41,
#   44,
#   45,
#   54,
#   55,
#   60,
#   63,
#   67,
#   74,
#   82,
#   85,
#   94,
#   97,
#   105,
#   106,
#   107,
#   111,
#   113,
#   116,
#   127,
#   138,
#   139,
#   148,
#   149],
#  [5, 26, 39, 57, 63, 64, 68, 74, 78, 93, 98, 100, 120, 176],
#  [0, 16, 20, 46, 58],
#  [0,
#   7,
#   9,
#   12,
#   14,
#   16,
#   19,
#   21,
#   23,
#   24,
#   26,
#   27,
#   28,
#   31,
#   38,
#   51,
#   53,
#   55,
#   59,
#   61,
#   66,
#   70,
#   73,
#   83,
#   86,
#   90,
#   92,
#   99,
#   102,
#   103,
#   109,
#   114,
#   119,
#   122,
#   126,
#   131,
#   134,
#   137,
#   144,
#   146,
#   150,
#   153,
#   164,
#   171,
#   174],
#  [0,
#   15,
#   16,
#   18,
#   22,
#   25,
#   31,
#   32,
#   33,
#   35,
#   36,
#   46,
#   49,
#   51,
#   54,
#   55,
#   56,
#   60,
#   61,
#   63,
#   65,
#   67,
#   69,
#   71,
#   72,
#   76,
#   82,
#   87,
#   91,
#   94,
#   104,
#   105,
#   106,
#   107,
#   111,
#   113,
#   115,
#   116,
#   119,
#   122,
#   124,
#   127,
#   128,
#   135,
#   136,
#   142,
#   143,
#   145,
#   148,
#   154,
#   156,
#   163,
#   167,
#   171,
#   172,
#   174],
#  [10,
#   11,
#   14,
#   18,
#   25,
#   26,
#   27,
#   35,
#   51,
#   53,
#   54,
#   59,
#   60,
#   61,
#   71,
#   73,
#   86,
#   90,
#   94,
#   111,
#   127,
#   135,
#   143,
#   145,
#   150,
#   154,
#   164,
#   166,
#   173],
#  [32, 62, 68, 95, 128, 129, 139, 141, 160],
#  [35, 39, 41, 44, 48, 56, 57, 60, 63, 64, 74, 78, 93, 98, 120, 160],
#  [39, 44, 48, 57, 63, 74, 78, 93, 98, 120, 140, 162],
#  [2,
#   8,
#   32,
#   35,
#   60,
#   65,
#   77,
#   87,
#   124,
#   129,
#   135,
#   136,
#   142,
#   145,
#   151,
#   160,
#   163,
#   165,
#   169,
#   172,
#   175,
#   176],
#  [7,
#   14,
#   16,
#   19,
#   21,
#   24,
#   26,
#   27,
#   29,
#   36,
#   37,
#   38,
#   51,
#   53,
#   55,
#   59,
#   73,
#   80,
#   82,
#   83,
#   86,
#   90,
#   92,
#   99,
#   102,
#   106,
#   107,
#   109,
#   113,
#   114,
#   117,
#   119,
#   126,
#   131,
#   132,
#   134,
#   137,
#   138,
#   144,
#   146,
#   150,
#   153],
#  [4,
#   11,
#   16,
#   18,
#   29,
#   36,
#   39,
#   40,
#   42,
#   54,
#   56,
#   60,
#   67,
#   71,
#   72,
#   76,
#   82,
#   84,
#   91,
#   105,
#   106,
#   108,
#   112,
#   127,
#   147,
#   152,
#   167,
#   176],
#  [5,
#   20,
#   32,
#   50,
#   57,
#   62,
#   76,
#   80,
#   81,
#   82,
#   84,
#   106,
#   108,
#   110,
#   112,
#   121,
#   126,
#   141,
#   145,
#   147,
#   152,
#   153,
#   159,
#   167,
#   168,
#   176,
#   179],
#  [15,
#   22,
#   23,
#   24,
#   25,
#   30,
#   31,
#   33,
#   60,
#   70,
#   83,
#   86,
#   87,
#   90,
#   94,
#   104,
#   108,
#   111,
#   123,
#   128,
#   131,
#   135,
#   148,
#   165,
#   166,
#   171,
#   174,
#   176,
#   179],
#  [7,
#   9,
#   10,
#   11,
#   14,
#   18,
#   22,
#   23,
#   24,
#   25,
#   26,
#   27,
#   28,
#   29,
#   31,
#   38,
#   48,
#   51,
#   55,
#   59,
#   69,
#   71,
#   83,
#   90,
#   92,
#   99,
#   102,
#   108,
#   111,
#   122,
#   123,
#   125,
#   131,
#   133,
#   134,
#   137,
#   144,
#   146,
#   148,
#   150,
#   153,
#   164,
#   170,
#   174,
#   175,
#   179],
#  [11,
#   18,
#   22,
#   23,
#   25,
#   28,
#   35,
#   36,
#   60,
#   61,
#   67,
#   70,
#   71,
#   76,
#   77,
#   94,
#   108,
#   111,
#   121,
#   123,
#   125,
#   127,
#   135,
#   143,
#   148,
#   154,
#   166,
#   170,
#   174,
#   178,
#   179],
#  [0,
#   7,
#   9,
#   10,
#   11,
#   14,
#   17,
#   24,
#   25,
#   29,
#   32,
#   35,
#   45,
#   51,
#   54,
#   60,
#   67,
#   77,
#   82,
#   104,
#   108,
#   111,
#   113,
#   125,
#   127,
#   129,
#   143,
#   145,
#   154,
#   165,
#   175,
#   176],
#  [16,
#   18,
#   23,
#   26,
#   27,
#   31,
#   50,
#   51,
#   53,
#   55,
#   59,
#   61,
#   66,
#   73,
#   83,
#   86,
#   90,
#   92,
#   94,
#   96,
#   103,
#   109,
#   117,
#   119,
#   126,
#   137,
#   146,
#   150,
#   154,
#   164,
#   173,
#   177],
#  [1, 5, 20, 39, 41, 56, 57, 63, 64, 74, 78, 93, 98, 100, 120, 121],
#  [3, 4, 5, 6, 24, 46, 75, 78, 85, 98, 120, 140, 177],
#  [3,
#   4,
#   41,
#   47,
#   60,
#   67,
#   68,
#   71,
#   81,
#   82,
#   84,
#   89,
#   91,
#   105,
#   106,
#   108,
#   111,
#   112,
#   113,
#   121,
#   135,
#   148,
#   152,
#   159,
#   167,
#   170,
#   179],
#  [2,
#   5,
#   7,
#   14,
#   22,
#   30,
#   38,
#   65,
#   71,
#   72,
#   79,
#   82,
#   88,
#   101,
#   108,
#   123,
#   125,
#   135,
#   158,
#   165,
#   169,
#   174,
#   175,
#   176,
#   179],
#  [5, 6, 23, 28, 39, 57, 63, 64, 74, 75, 81, 93, 98, 100, 120],
#  [7,
#   9,
#   10,
#   11,
#   14,
#   20,
#   22,
#   26,
#   27,
#   29,
#   37,
#   38,
#   43,
#   47,
#   48,
#   50,
#   53,
#   54,
#   55,
#   77,
#   79,
#   87,
#   88,
#   102,
#   104,
#   107,
#   108,
#   115,
#   119,
#   123,
#   125,
#   126,
#   131,
#   133,
#   134,
#   135,
#   136,
#   137,
#   144,
#   145,
#   146,
#   150,
#   163,
#   165,
#   166,
#   171,
#   174,
#   175,
#   176,
#   178],
#  [20,
#   23,
#   24,
#   31,
#   36,
#   37,
#   38,
#   40,
#   47,
#   50,
#   55,
#   66,
#   68,
#   80,
#   82,
#   83,
#   84,
#   92,
#   94,
#   104,
#   106,
#   112,
#   114,
#   117,
#   119,
#   146,
#   147,
#   152,
#   159,
#   167,
#   176,
#   179],
#  [3,
#   37,
#   41,
#   42,
#   47,
#   50,
#   68,
#   76,
#   78,
#   81,
#   82,
#   84,
#   86,
#   89,
#   91,
#   94,
#   106,
#   121,
#   123,
#   135,
#   148,
#   152,
#   159,
#   170,
#   179],
#  [0,
#   7,
#   9,
#   11,
#   14,
#   16,
#   17,
#   24,
#   27,
#   29,
#   32,
#   35,
#   36,
#   37,
#   41,
#   42,
#   46,
#   47,
#   48,
#   50,
#   51,
#   55,
#   56,
#   60,
#   66,
#   67,
#   68,
#   72,
#   76,
#   77,
#   80,
#   81,
#   82,
#   83,
#   84,
#   88,
#   89,
#   91,
#   92,
#   96,
#   97,
#   103,
#   104,
#   105,
#   106,
#   108,
#   112,
#   113,
#   114,
#   116,
#   117,
#   119,
#   121,
#   126,
#   132,
#   135,
#   138,
#   140,
#   145,
#   146,
#   147,
#   148,
#   149,
#   152,
#   159,
#   170,
#   171,
#   176,
#   179],
#  [16,
#   20,
#   23,
#   24,
#   26,
#   29,
#   31,
#   36,
#   37,
#   40,
#   47,
#   50,
#   51,
#   53,
#   55,
#   59,
#   66,
#   69,
#   70,
#   73,
#   80,
#   82,
#   83,
#   84,
#   86,
#   90,
#   92,
#   94,
#   99,
#   103,
#   106,
#   112,
#   114,
#   117,
#   119,
#   126,
#   131,
#   132,
#   134,
#   137,
#   138,
#   146,
#   147,
#   148,
#   149,
#   152,
#   153,
#   157,
#   159,
#   162,
#   164,
#   167],
#  [3,
#   18,
#   20,
#   27,
#   29,
#   36,
#   42,
#   47,
#   50,
#   51,
#   67,
#   68,
#   76,
#   80,
#   81,
#   82,
#   83,
#   84,
#   86,
#   89,
#   94,
#   96,
#   106,
#   112,
#   114,
#   117,
#   147,
#   149,
#   152,
#   159,
#   167,
#   170,
#   176,
#   179],
#  [41, 56, 75, 85, 97, 113, 116, 170],
#  [12,
#   16,
#   20,
#   23,
#   24,
#   27,
#   31,
#   36,
#   37,
#   50,
#   51,
#   53,
#   55,
#   59,
#   61,
#   66,
#   69,
#   73,
#   81,
#   83,
#   84,
#   86,
#   89,
#   90,
#   92,
#   94,
#   103,
#   106,
#   114,
#   117,
#   121,
#   126,
#   162,
#   167],
#  [7,
#   10,
#   14,
#   15,
#   22,
#   25,
#   32,
#   33,
#   35,
#   60,
#   65,
#   69,
#   79,
#   87,
#   88,
#   104,
#   108,
#   111,
#   115,
#   118,
#   119,
#   124,
#   127,
#   129,
#   135,
#   136,
#   142,
#   143,
#   145,
#   151,
#   156,
#   160,
#   161,
#   163,
#   165,
#   166,
#   169,
#   171,
#   172,
#   174,
#   175,
#   176,
#   178,
#   179],
#  [2,
#   5,
#   7,
#   14,
#   22,
#   25,
#   30,
#   32,
#   33,
#   35,
#   38,
#   41,
#   46,
#   77,
#   79,
#   82,
#   87,
#   88,
#   101,
#   119,
#   125,
#   126,
#   130,
#   131,
#   135,
#   145,
#   151,
#   158,
#   163,
#   165,
#   171,
#   172,
#   174,
#   175,
#   176,
#   178,
#   179],
#  [4,
#   41,
#   42,
#   47,
#   50,
#   76,
#   81,
#   82,
#   84,
#   86,
#   89,
#   91,
#   106,
#   112,
#   121,
#   148,
#   152,
#   159,
#   170,
#   179],
#  [9,
#   14,
#   16,
#   18,
#   23,
#   24,
#   26,
#   27,
#   29,
#   31,
#   38,
#   51,
#   53,
#   55,
#   59,
#   61,
#   66,
#   69,
#   70,
#   73,
#   83,
#   86,
#   90,
#   92,
#   94,
#   103,
#   109,
#   114,
#   119,
#   126,
#   137,
#   139,
#   146,
#   150,
#   153,
#   154,
#   164,
#   171,
#   173,
#   174],
#  [3, 42, 47, 60, 67, 76, 81, 82, 89, 91, 105, 106, 121, 148, 152, 167, 170],
#  [6,
#   14,
#   19,
#   24,
#   26,
#   27,
#   31,
#   36,
#   38,
#   49,
#   50,
#   51,
#   53,
#   55,
#   59,
#   66,
#   70,
#   73,
#   80,
#   82,
#   83,
#   86,
#   90,
#   92,
#   94,
#   106,
#   107,
#   109,
#   114,
#   117,
#   119,
#   125,
#   126,
#   128,
#   130,
#   131,
#   132,
#   134,
#   137,
#   138,
#   146,
#   153,
#   164,
#   167,
#   174],
#  [1, 39, 42, 57, 63, 64, 74, 78, 98, 100, 120],
#  [12,
#   16,
#   20,
#   23,
#   31,
#   36,
#   37,
#   50,
#   53,
#   56,
#   60,
#   61,
#   69,
#   71,
#   73,
#   80,
#   81,
#   83,
#   84,
#   86,
#   90,
#   92,
#   94,
#   103,
#   107,
#   121,
#   123,
#   135,
#   148,
#   152,
#   162,
#   167,
#   171,
#   173,
#   177],
#  [17, 32, 62, 128, 129, 139, 157, 160],
#  [18, 50, 51, 53, 73, 82, 84, 96, 106, 112, 117, 121, 147, 152, 159, 173, 177],
#  [3, 24, 31, 37, 42, 55, 56, 82, 85, 97, 99, 113, 126, 130, 138, 175],
#  [1, 5, 6, 39, 57, 63, 64, 74, 75, 78, 93, 98, 100, 120, 176],
#  [7,
#   8,
#   9,
#   10,
#   11,
#   14,
#   16,
#   18,
#   24,
#   26,
#   27,
#   28,
#   29,
#   55,
#   59,
#   66,
#   70,
#   83,
#   97,
#   99,
#   102,
#   113,
#   119,
#   122,
#   123,
#   131,
#   133,
#   134,
#   137,
#   144,
#   146,
#   149,
#   150,
#   164,
#   174,
#   175,
#   176],
#  [57, 74, 78, 93, 98, 120, 179],
#  [2,
#   5,
#   6,
#   8,
#   15,
#   19,
#   21,
#   22,
#   28,
#   30,
#   33,
#   52,
#   77,
#   88,
#   101,
#   123,
#   130,
#   131,
#   135,
#   140,
#   158,
#   172,
#   174,
#   175,
#   176,
#   179],
#  [7,
#   9,
#   10,
#   11,
#   14,
#   18,
#   26,
#   27,
#   29,
#   38,
#   54,
#   55,
#   59,
#   66,
#   70,
#   79,
#   99,
#   102,
#   104,
#   108,
#   119,
#   125,
#   131,
#   133,
#   134,
#   137,
#   144,
#   146,
#   150,
#   155,
#   164,
#   166,
#   174,
#   175,
#   176],
#  [0,
#   12,
#   16,
#   20,
#   23,
#   24,
#   28,
#   31,
#   36,
#   46,
#   51,
#   53,
#   59,
#   73,
#   82,
#   83,
#   86,
#   90,
#   94,
#   113,
#   116,
#   117,
#   118,
#   130,
#   132,
#   140,
#   149,
#   157,
#   161,
#   162],
#  [7,
#   9,
#   10,
#   14,
#   22,
#   25,
#   32,
#   37,
#   47,
#   60,
#   69,
#   72,
#   79,
#   80,
#   82,
#   87,
#   102,
#   108,
#   110,
#   115,
#   117,
#   119,
#   124,
#   125,
#   127,
#   135,
#   136,
#   142,
#   145,
#   151,
#   156,
#   161,
#   163,
#   165,
#   169,
#   171,
#   175,
#   178,
#   179],
#  [4,
#   16,
#   34,
#   40,
#   56,
#   60,
#   67,
#   76,
#   82,
#   91,
#   105,
#   106,
#   112,
#   121,
#   126,
#   147,
#   152,
#   176],
#  [3,
#   4,
#   42,
#   47,
#   50,
#   51,
#   56,
#   60,
#   66,
#   67,
#   68,
#   76,
#   80,
#   81,
#   82,
#   83,
#   84,
#   86,
#   89,
#   91,
#   92,
#   96,
#   105,
#   106,
#   112,
#   117,
#   119,
#   126,
#   132,
#   138,
#   152,
#   159,
#   167,
#   170],
#  [7,
#   8,
#   10,
#   14,
#   16,
#   18,
#   27,
#   29,
#   33,
#   37,
#   38,
#   46,
#   54,
#   55,
#   56,
#   60,
#   66,
#   79,
#   92,
#   94,
#   107,
#   108,
#   109,
#   111,
#   115,
#   119,
#   122,
#   125,
#   126,
#   127,
#   134,
#   135,
#   136,
#   143,
#   145,
#   147,
#   149,
#   151,
#   154,
#   155,
#   156,
#   160,
#   163,
#   166,
#   167,
#   174,
#   175,
#   176],
#  [7,
#   9,
#   10,
#   11,
#   14,
#   15,
#   18,
#   22,
#   23,
#   25,
#   27,
#   29,
#   30,
#   35,
#   38,
#   47,
#   48,
#   54,
#   67,
#   68,
#   69,
#   70,
#   71,
#   72,
#   76,
#   77,
#   79,
#   82,
#   87,
#   102,
#   104,
#   107,
#   108,
#   111,
#   123,
#   125,
#   127,
#   133,
#   134,
#   135,
#   136,
#   137,
#   142,
#   143,
#   144,
#   145,
#   146,
#   148,
#   150,
#   154,
#   155,
#   163,
#   164,
#   165,
#   166,
#   170,
#   174,
#   175,
#   176,
#   178,
#   179],
#  [7,
#   14,
#   19,
#   21,
#   26,
#   36,
#   38,
#   51,
#   53,
#   59,
#   66,
#   73,
#   90,
#   92,
#   107,
#   119,
#   126,
#   139,
#   146,
#   153,
#   154,
#   155,
#   166,
#   174,
#   175,
#   178],
#  [26, 49, 68, 104, 110, 114, 116, 117, 128, 139, 141, 156, 168],
#  [7,
#   18,
#   22,
#   25,
#   33,
#   35,
#   54,
#   56,
#   60,
#   61,
#   69,
#   70,
#   71,
#   72,
#   76,
#   87,
#   107,
#   108,
#   111,
#   115,
#   125,
#   127,
#   135,
#   136,
#   142,
#   143,
#   145,
#   148,
#   153,
#   154,
#   155,
#   156,
#   163,
#   165,
#   166,
#   170,
#   174,
#   175,
#   176,
#   178],
#  [47,
#   50,
#   67,
#   68,
#   76,
#   80,
#   82,
#   83,
#   84,
#   89,
#   96,
#   105,
#   106,
#   117,
#   120,
#   121,
#   132,
#   152,
#   159,
#   167,
#   170,
#   176,
#   179],
#  [16,
#   25,
#   28,
#   32,
#   45,
#   56,
#   60,
#   66,
#   72,
#   76,
#   82,
#   85,
#   97,
#   99,
#   103,
#   113,
#   116,
#   117,
#   126,
#   135,
#   148,
#   149,
#   151,
#   160,
#   161,
#   165,
#   172,
#   176,
#   179],
#  [24,
#   26,
#   31,
#   38,
#   49,
#   50,
#   51,
#   55,
#   59,
#   66,
#   80,
#   82,
#   83,
#   84,
#   86,
#   90,
#   92,
#   110,
#   114,
#   117,
#   119,
#   128,
#   131,
#   132,
#   134,
#   137,
#   138,
#   147,
#   153,
#   159,
#   167],
#  [16,
#   22,
#   25,
#   33,
#   35,
#   37,
#   46,
#   47,
#   60,
#   79,
#   87,
#   104,
#   107,
#   111,
#   115,
#   118,
#   119,
#   127,
#   135,
#   136,
#   142,
#   143,
#   149,
#   151,
#   156,
#   161,
#   163,
#   166,
#   172,
#   178,
#   179],
#  [0, 16, 49, 56, 60, 82, 85, 103, 110, 113, 116, 135, 140, 148, 161, 162, 179],
#  [12,
#   16,
#   36,
#   46,
#   51,
#   66,
#   73,
#   80,
#   82,
#   83,
#   84,
#   86,
#   92,
#   96,
#   103,
#   104,
#   106,
#   110,
#   112,
#   113,
#   114,
#   117,
#   118,
#   119,
#   126,
#   130,
#   132,
#   138,
#   153,
#   157,
#   159,
#   161,
#   172,
#   179],
#  [12,
#   16,
#   17,
#   20,
#   25,
#   33,
#   35,
#   46,
#   87,
#   103,
#   115,
#   117,
#   122,
#   130,
#   142,
#   149,
#   151,
#   157,
#   161,
#   178],
#  [7,
#   9,
#   10,
#   11,
#   12,
#   14,
#   24,
#   26,
#   27,
#   29,
#   35,
#   36,
#   37,
#   38,
#   51,
#   53,
#   55,
#   59,
#   60,
#   66,
#   73,
#   79,
#   80,
#   82,
#   83,
#   87,
#   88,
#   90,
#   92,
#   99,
#   102,
#   104,
#   106,
#   107,
#   109,
#   114,
#   115,
#   117,
#   119,
#   122,
#   125,
#   126,
#   131,
#   133,
#   134,
#   137,
#   138,
#   144,
#   146,
#   150,
#   164,
#   171,
#   174,
#   175,
#   176],
#  [4, 5, 39, 57, 63, 64, 74, 75, 78, 93, 98, 100, 112, 120, 176],
#  [20,
#   31,
#   37,
#   48,
#   50,
#   68,
#   71,
#   74,
#   76,
#   81,
#   82,
#   86,
#   89,
#   91,
#   94,
#   96,
#   105,
#   112,
#   121,
#   123,
#   135,
#   147,
#   148,
#   152,
#   159,
#   167,
#   170,
#   179],
#  [10,
#   12,
#   16,
#   29,
#   32,
#   35,
#   59,
#   60,
#   70,
#   99,
#   107,
#   118,
#   119,
#   122,
#   134,
#   136,
#   137,
#   139,
#   142,
#   145,
#   147,
#   150,
#   164,
#   175,
#   176],
#  [8,
#   10,
#   11,
#   14,
#   15,
#   18,
#   22,
#   23,
#   27,
#   28,
#   29,
#   30,
#   31,
#   50,
#   54,
#   69,
#   70,
#   71,
#   77,
#   79,
#   81,
#   94,
#   99,
#   101,
#   108,
#   121,
#   123,
#   128,
#   131,
#   133,
#   135,
#   137,
#   146,
#   148,
#   150,
#   152,
#   158,
#   164,
#   166,
#   170,
#   174,
#   179],
#  [22,
#   32,
#   35,
#   48,
#   50,
#   60,
#   65,
#   87,
#   104,
#   124,
#   129,
#   135,
#   136,
#   142,
#   143,
#   145,
#   154,
#   163,
#   165,
#   169,
#   171,
#   179],
#  [7,
#   9,
#   10,
#   11,
#   14,
#   22,
#   25,
#   26,
#   27,
#   29,
#   35,
#   38,
#   48,
#   70,
#   71,
#   72,
#   77,
#   79,
#   88,
#   92,
#   102,
#   104,
#   107,
#   108,
#   111,
#   119,
#   130,
#   133,
#   134,
#   135,
#   136,
#   137,
#   143,
#   144,
#   145,
#   146,
#   154,
#   155,
#   163,
#   164,
#   165,
#   166,
#   174,
#   175,
#   176,
#   178],
#  [5,
#   7,
#   14,
#   18,
#   19,
#   26,
#   27,
#   37,
#   38,
#   51,
#   53,
#   55,
#   59,
#   66,
#   68,
#   73,
#   79,
#   82,
#   83,
#   86,
#   88,
#   90,
#   92,
#   97,
#   105,
#   106,
#   107,
#   109,
#   113,
#   117,
#   119,
#   126,
#   130,
#   131,
#   138,
#   145,
#   146,
#   153,
#   155,
#   158,
#   171,
#   172,
#   174,
#   175,
#   176],
#  [7,
#   10,
#   14,
#   18,
#   21,
#   22,
#   25,
#   27,
#   32,
#   33,
#   54,
#   56,
#   60,
#   61,
#   67,
#   71,
#   72,
#   87,
#   104,
#   107,
#   108,
#   111,
#   115,
#   127,
#   135,
#   136,
#   142,
#   143,
#   145,
#   154,
#   155,
#   156,
#   160,
#   163,
#   165,
#   166,
#   172,
#   174,
#   175,
#   176,
#   178],
#  [9,
#   11,
#   18,
#   26,
#   27,
#   32,
#   38,
#   49,
#   54,
#   55,
#   60,
#   62,
#   69,
#   92,
#   95,
#   110,
#   114,
#   123,
#   128,
#   129,
#   138,
#   139,
#   160,
#   164,
#   167],
#  [2,
#   9,
#   14,
#   17,
#   19,
#   21,
#   32,
#   62,
#   65,
#   72,
#   87,
#   95,
#   124,
#   128,
#   129,
#   139,
#   160,
#   169,
#   173,
#   177],
#  [4,
#   6,
#   20,
#   24,
#   33,
#   36,
#   46,
#   51,
#   88,
#   92,
#   97,
#   101,
#   103,
#   117,
#   118,
#   125,
#   126,
#   130,
#   140,
#   157],
#  [7,
#   9,
#   14,
#   18,
#   22,
#   24,
#   26,
#   27,
#   38,
#   55,
#   59,
#   66,
#   69,
#   70,
#   79,
#   83,
#   88,
#   92,
#   99,
#   101,
#   102,
#   114,
#   119,
#   123,
#   126,
#   132,
#   133,
#   134,
#   137,
#   138,
#   142,
#   144,
#   146,
#   150,
#   153,
#   158,
#   164,
#   174,
#   175,
#   176,
#   179],
#  [16,
#   24,
#   26,
#   38,
#   49,
#   55,
#   66,
#   82,
#   83,
#   92,
#   103,
#   106,
#   112,
#   114,
#   117,
#   131,
#   132,
#   134,
#   137,
#   138,
#   153,
#   159],
#  [7,
#   9,
#   10,
#   11,
#   14,
#   18,
#   26,
#   27,
#   29,
#   38,
#   55,
#   70,
#   79,
#   99,
#   102,
#   108,
#   119,
#   123,
#   125,
#   131,
#   134,
#   137,
#   144,
#   146,
#   150,
#   164,
#   174,
#   175,
#   176],
#  [7,
#   9,
#   10,
#   11,
#   14,
#   18,
#   23,
#   24,
#   26,
#   27,
#   29,
#   38,
#   48,
#   51,
#   55,
#   59,
#   66,
#   70,
#   79,
#   83,
#   92,
#   99,
#   102,
#   107,
#   108,
#   114,
#   119,
#   122,
#   125,
#   131,
#   132,
#   133,
#   137,
#   138,
#   144,
#   146,
#   149,
#   150,
#   153,
#   164,
#   174,
#   175,
#   176],
#  [0,
#   2,
#   8,
#   9,
#   10,
#   11,
#   14,
#   15,
#   18,
#   22,
#   23,
#   25,
#   27,
#   30,
#   33,
#   37,
#   41,
#   46,
#   47,
#   50,
#   54,
#   60,
#   61,
#   65,
#   69,
#   71,
#   76,
#   77,
#   79,
#   81,
#   82,
#   87,
#   88,
#   94,
#   101,
#   104,
#   107,
#   108,
#   111,
#   113,
#   115,
#   116,
#   121,
#   123,
#   124,
#   125,
#   127,
#   135,
#   136,
#   140,
#   142,
#   143,
#   148,
#   149,
#   151,
#   154,
#   156,
#   160,
#   161,
#   163,
#   166,
#   169,
#   170,
#   171,
#   172,
#   174,
#   176,
#   178,
#   179],
#  [7,
#   9,
#   10,
#   11,
#   14,
#   18,
#   22,
#   25,
#   27,
#   32,
#   33,
#   35,
#   38,
#   54,
#   60,
#   65,
#   79,
#   87,
#   104,
#   107,
#   108,
#   111,
#   115,
#   122,
#   124,
#   125,
#   127,
#   135,
#   136,
#   137,
#   142,
#   143,
#   145,
#   150,
#   151,
#   154,
#   155,
#   156,
#   160,
#   163,
#   164,
#   165,
#   166,
#   169,
#   172,
#   174,
#   175,
#   176,
#   178],
#  [0,
#   7,
#   9,
#   10,
#   11,
#   14,
#   16,
#   18,
#   22,
#   23,
#   24,
#   26,
#   27,
#   28,
#   29,
#   38,
#   48,
#   51,
#   53,
#   55,
#   59,
#   66,
#   70,
#   73,
#   79,
#   83,
#   90,
#   92,
#   99,
#   102,
#   108,
#   114,
#   119,
#   122,
#   123,
#   125,
#   131,
#   132,
#   133,
#   134,
#   136,
#   137,
#   140,
#   144,
#   146,
#   149,
#   150,
#   153,
#   164,
#   174,
#   175,
#   176],
#  [24,
#   26,
#   38,
#   49,
#   55,
#   56,
#   66,
#   82,
#   83,
#   92,
#   97,
#   106,
#   114,
#   117,
#   119,
#   126,
#   128,
#   131,
#   132,
#   134,
#   138,
#   153,
#   159],
#  [6,
#   14,
#   26,
#   32,
#   45,
#   54,
#   56,
#   62,
#   90,
#   95,
#   109,
#   110,
#   122,
#   128,
#   129,
#   139,
#   141,
#   145,
#   154,
#   160,
#   168,
#   171,
#   173,
#   174,
#   177],
#  [0,
#   12,
#   16,
#   19,
#   23,
#   24,
#   28,
#   29,
#   31,
#   36,
#   37,
#   39,
#   44,
#   46,
#   47,
#   48,
#   51,
#   64,
#   75,
#   82,
#   101,
#   103,
#   116,
#   130,
#   135,
#   137,
#   146,
#   148,
#   149,
#   162],
#  [62, 68, 110, 139, 168, 177, 179],
#  [7,
#   10,
#   14,
#   18,
#   22,
#   25,
#   32,
#   33,
#   35,
#   54,
#   60,
#   65,
#   87,
#   104,
#   108,
#   111,
#   115,
#   118,
#   122,
#   124,
#   127,
#   131,
#   135,
#   136,
#   142,
#   143,
#   145,
#   150,
#   151,
#   154,
#   155,
#   156,
#   160,
#   163,
#   164,
#   165,
#   166,
#   172,
#   174,
#   175,
#   176,
#   178],
#  [7,
#   14,
#   15,
#   18,
#   21,
#   22,
#   25,
#   33,
#   35,
#   54,
#   60,
#   61,
#   71,
#   72,
#   87,
#   107,
#   108,
#   111,
#   115,
#   124,
#   125,
#   127,
#   135,
#   136,
#   142,
#   145,
#   150,
#   154,
#   156,
#   163,
#   165,
#   166,
#   174,
#   175,
#   178],
#  [7,
#   9,
#   10,
#   11,
#   14,
#   18,
#   26,
#   27,
#   29,
#   38,
#   51,
#   55,
#   59,
#   66,
#   70,
#   79,
#   99,
#   102,
#   108,
#   119,
#   125,
#   131,
#   133,
#   134,
#   137,
#   144,
#   146,
#   150,
#   164,
#   174,
#   175,
#   176],
#  [5,
#   7,
#   9,
#   10,
#   11,
#   14,
#   18,
#   22,
#   25,
#   27,
#   32,
#   35,
#   54,
#   60,
#   61,
#   65,
#   68,
#   72,
#   79,
#   82,
#   87,
#   88,
#   104,
#   107,
#   108,
#   111,
#   122,
#   124,
#   125,
#   126,
#   127,
#   136,
#   139,
#   142,
#   143,
#   145,
#   146,
#   153,
#   154,
#   155,
#   156,
#   160,
#   163,
#   164,
#   165,
#   174,
#   175,
#   176,
#   178],
#  [0,
#   7,
#   9,
#   10,
#   11,
#   14,
#   18,
#   19,
#   21,
#   22,
#   23,
#   24,
#   26,
#   27,
#   28,
#   29,
#   36,
#   38,
#   48,
#   50,
#   51,
#   53,
#   54,
#   55,
#   59,
#   66,
#   70,
#   73,
#   79,
#   80,
#   82,
#   83,
#   90,
#   92,
#   99,
#   102,
#   108,
#   109,
#   119,
#   123,
#   125,
#   126,
#   131,
#   133,
#   134,
#   137,
#   140,
#   144,
#   145,
#   150,
#   153,
#   155,
#   158,
#   164,
#   174,
#   175,
#   176],
#  [13,
#   16,
#   20,
#   31,
#   37,
#   40,
#   47,
#   50,
#   55,
#   67,
#   68,
#   80,
#   82,
#   83,
#   84,
#   96,
#   105,
#   107,
#   114,
#   121,
#   122,
#   147,
#   152,
#   159,
#   167,
#   176],
#  [15,
#   16,
#   23,
#   25,
#   28,
#   30,
#   31,
#   37,
#   47,
#   50,
#   52,
#   56,
#   60,
#   69,
#   70,
#   71,
#   76,
#   81,
#   82,
#   83,
#   89,
#   91,
#   94,
#   108,
#   111,
#   113,
#   116,
#   121,
#   123,
#   135,
#   140,
#   152,
#   158,
#   162,
#   166,
#   170,
#   172,
#   179],
#  [0,
#   8,
#   12,
#   16,
#   18,
#   20,
#   29,
#   36,
#   37,
#   45,
#   46,
#   47,
#   56,
#   82,
#   83,
#   84,
#   99,
#   103,
#   107,
#   113,
#   115,
#   118,
#   134,
#   135,
#   137,
#   140,
#   151,
#   157,
#   160,
#   161],
#  [7,
#   9,
#   10,
#   11,
#   14,
#   18,
#   23,
#   25,
#   26,
#   27,
#   28,
#   29,
#   38,
#   51,
#   53,
#   54,
#   55,
#   59,
#   61,
#   66,
#   70,
#   73,
#   79,
#   90,
#   99,
#   102,
#   108,
#   119,
#   122,
#   123,
#   131,
#   133,
#   134,
#   136,
#   137,
#   142,
#   143,
#   144,
#   146,
#   150,
#   154,
#   155,
#   164,
#   166,
#   174,
#   175,
#   176,
#   178],
#  [2,
#   8,
#   22,
#   25,
#   32,
#   65,
#   87,
#   88,
#   104,
#   107,
#   113,
#   115,
#   118,
#   135,
#   136,
#   142,
#   149,
#   151,
#   156,
#   160,
#   161,
#   163,
#   165,
#   169,
#   172,
#   179],
#  [6,
#   20,
#   31,
#   34,
#   37,
#   40,
#   47,
#   50,
#   67,
#   68,
#   76,
#   80,
#   81,
#   82,
#   83,
#   84,
#   89,
#   91,
#   94,
#   96,
#   105,
#   106,
#   112,
#   121,
#   123,
#   147,
#   148,
#   152,
#   159,
#   167,
#   170,
#   176,
#   179],
#  [7,
#   18,
#   21,
#   24,
#   26,
#   27,
#   36,
#   38,
#   49,
#   50,
#   51,
#   53,
#   55,
#   59,
#   66,
#   68,
#   70,
#   83,
#   90,
#   92,
#   109,
#   111,
#   114,
#   117,
#   126,
#   131,
#   132,
#   134,
#   137,
#   138,
#   145,
#   146,
#   153,
#   154,
#   155,
#   157,
#   164,
#   174,
#   175],
#  [7,
#   14,
#   18,
#   21,
#   22,
#   25,
#   27,
#   32,
#   33,
#   35,
#   51,
#   53,
#   54,
#   60,
#   61,
#   71,
#   72,
#   73,
#   90,
#   107,
#   108,
#   109,
#   111,
#   124,
#   125,
#   127,
#   135,
#   136,
#   139,
#   142,
#   143,
#   145,
#   150,
#   153,
#   155,
#   156,
#   160,
#   163,
#   164,
#   165,
#   166,
#   174,
#   175,
#   176,
#   178],
#  [7,
#   18,
#   21,
#   27,
#   33,
#   38,
#   54,
#   102,
#   107,
#   108,
#   109,
#   111,
#   125,
#   126,
#   127,
#   136,
#   142,
#   145,
#   146,
#   150,
#   153,
#   154,
#   156,
#   164,
#   174,
#   175,
#   176,
#   178],
#  [7,
#   14,
#   21,
#   22,
#   25,
#   33,
#   54,
#   60,
#   87,
#   104,
#   107,
#   110,
#   111,
#   115,
#   127,
#   135,
#   136,
#   142,
#   143,
#   145,
#   151,
#   154,
#   155,
#   156,
#   163,
#   165,
#   166,
#   174,
#   175,
#   178],
#  [20, 46, 83, 95, 103, 117, 118, 130, 149, 153, 157],
#  [77, 88, 101, 123, 126, 131, 146, 148, 158, 179],
#  [47,
#   50,
#   68,
#   76,
#   80,
#   81,
#   82,
#   83,
#   84,
#   89,
#   96,
#   106,
#   112,
#   114,
#   117,
#   121,
#   132,
#   138,
#   147,
#   152,
#   159,
#   167,
#   170,
#   179],
#  [2,
#   8,
#   9,
#   11,
#   18,
#   22,
#   27,
#   32,
#   45,
#   54,
#   62,
#   63,
#   65,
#   87,
#   95,
#   107,
#   113,
#   127,
#   128,
#   129,
#   135,
#   136,
#   139,
#   142,
#   145,
#   149,
#   151,
#   154,
#   160,
#   165,
#   169,
#   172,
#   173,
#   174,
#   176],
#  [0,
#   12,
#   16,
#   22,
#   25,
#   46,
#   87,
#   103,
#   104,
#   113,
#   115,
#   116,
#   117,
#   118,
#   135,
#   149,
#   151,
#   161,
#   163,
#   169,
#   172,
#   179],
#  [6, 16, 36, 39, 44, 46, 47, 48, 50, 64, 83, 86, 94, 103, 116, 140, 148, 162],
#  [7,
#   15,
#   22,
#   25,
#   35,
#   60,
#   65,
#   79,
#   87,
#   88,
#   104,
#   107,
#   108,
#   111,
#   115,
#   124,
#   125,
#   127,
#   135,
#   136,
#   142,
#   143,
#   145,
#   151,
#   154,
#   156,
#   161,
#   165,
#   166,
#   170,
#   174,
#   178,
#   179],
#  [7,
#   9,
#   10,
#   11,
#   14,
#   18,
#   22,
#   23,
#   24,
#   26,
#   27,
#   29,
#   38,
#   51,
#   53,
#   55,
#   59,
#   61,
#   70,
#   73,
#   83,
#   90,
#   92,
#   99,
#   102,
#   108,
#   119,
#   122,
#   123,
#   125,
#   128,
#   131,
#   133,
#   134,
#   136,
#   137,
#   142,
#   144,
#   145,
#   146,
#   150,
#   153,
#   154,
#   155,
#   164,
#   174,
#   175,
#   176],
#  [14,
#   22,
#   25,
#   32,
#   35,
#   65,
#   69,
#   72,
#   77,
#   79,
#   87,
#   88,
#   104,
#   108,
#   111,
#   113,
#   124,
#   125,
#   127,
#   136,
#   142,
#   143,
#   145,
#   151,
#   154,
#   156,
#   160,
#   163,
#   166,
#   169,
#   174,
#   175,
#   176,
#   178],
#  [7,
#   14,
#   21,
#   22,
#   25,
#   26,
#   28,
#   54,
#   61,
#   69,
#   71,
#   79,
#   87,
#   102,
#   107,
#   108,
#   109,
#   111,
#   115,
#   123,
#   125,
#   127,
#   135,
#   136,
#   142,
#   143,
#   148,
#   150,
#   154,
#   156,
#   163,
#   165,
#   166,
#   170,
#   174,
#   175,
#   178],
#  [20,
#   31,
#   36,
#   37,
#   40,
#   50,
#   55,
#   60,
#   67,
#   68,
#   76,
#   80,
#   83,
#   84,
#   86,
#   91,
#   92,
#   94,
#   106,
#   107,
#   112,
#   114,
#   121,
#   128,
#   147,
#   152,
#   159,
#   167,
#   176],
#  [68, 110, 139, 141, 168, 177],
#  [2, 9, 32, 65, 77, 87, 104, 124, 129, 135, 136, 151, 160, 161, 165, 169, 172],
#  [3,
#   37,
#   42,
#   47,
#   48,
#   50,
#   70,
#   71,
#   76,
#   81,
#   82,
#   84,
#   85,
#   89,
#   91,
#   106,
#   108,
#   111,
#   112,
#   121,
#   123,
#   135,
#   148,
#   152,
#   159,
#   163,
#   166,
#   170,
#   179],
#  [14,
#   22,
#   31,
#   32,
#   51,
#   55,
#   59,
#   60,
#   69,
#   79,
#   82,
#   87,
#   88,
#   90,
#   94,
#   104,
#   119,
#   124,
#   126,
#   135,
#   139,
#   171,
#   173,
#   174,
#   176],
#  [2,
#   8,
#   21,
#   22,
#   25,
#   28,
#   32,
#   35,
#   52,
#   60,
#   65,
#   87,
#   88,
#   101,
#   113,
#   115,
#   117,
#   126,
#   127,
#   135,
#   136,
#   142,
#   148,
#   151,
#   160,
#   161,
#   169,
#   172,
#   179],
#  [6, 50, 53, 54, 61, 73, 90, 94, 96, 129, 139, 160, 171, 176, 177],
#  [0,
#   7,
#   9,
#   10,
#   11,
#   14,
#   18,
#   22,
#   23,
#   24,
#   25,
#   26,
#   27,
#   29,
#   30,
#   38,
#   54,
#   55,
#   59,
#   60,
#   69,
#   70,
#   71,
#   77,
#   79,
#   87,
#   88,
#   90,
#   92,
#   99,
#   101,
#   102,
#   107,
#   108,
#   109,
#   111,
#   119,
#   123,
#   125,
#   126,
#   127,
#   131,
#   133,
#   134,
#   135,
#   136,
#   137,
#   139,
#   142,
#   143,
#   144,
#   145,
#   146,
#   150,
#   153,
#   154,
#   155,
#   156,
#   160,
#   163,
#   164,
#   165,
#   166,
#   171,
#   174,
#   175,
#   176,
#   178],
#  [5,
#   7,
#   9,
#   10,
#   11,
#   14,
#   18,
#   22,
#   26,
#   27,
#   29,
#   32,
#   38,
#   54,
#   55,
#   65,
#   70,
#   72,
#   77,
#   79,
#   87,
#   88,
#   97,
#   99,
#   101,
#   102,
#   104,
#   107,
#   108,
#   109,
#   111,
#   119,
#   122,
#   125,
#   126,
#   127,
#   131,
#   133,
#   134,
#   136,
#   137,
#   142,
#   143,
#   144,
#   145,
#   146,
#   150,
#   153,
#   154,
#   155,
#   156,
#   164,
#   165,
#   166,
#   174,
#   175,
#   176,
#   178],
#  [2,
#   5,
#   7,
#   9,
#   10,
#   11,
#   14,
#   18,
#   22,
#   24,
#   25,
#   26,
#   27,
#   29,
#   32,
#   33,
#   36,
#   37,
#   38,
#   40,
#   51,
#   54,
#   55,
#   57,
#   65,
#   67,
#   68,
#   69,
#   72,
#   77,
#   79,
#   80,
#   82,
#   84,
#   87,
#   88,
#   98,
#   99,
#   101,
#   102,
#   105,
#   107,
#   108,
#   111,
#   112,
#   113,
#   119,
#   120,
#   122,
#   125,
#   126,
#   127,
#   131,
#   133,
#   134,
#   135,
#   136,
#   137,
#   142,
#   144,
#   145,
#   146,
#   147,
#   150,
#   152,
#   154,
#   155,
#   160,
#   164,
#   165,
#   167,
#   171,
#   173,
#   174,
#   175,
#   176,
#   179],
#  [6, 50, 73, 75, 94, 96, 129, 139, 141, 168, 173, 177],
#  [7,
#   14,
#   21,
#   22,
#   25,
#   33,
#   35,
#   54,
#   71,
#   79,
#   87,
#   88,
#   104,
#   108,
#   109,
#   111,
#   115,
#   118,
#   125,
#   127,
#   135,
#   136,
#   142,
#   143,
#   145,
#   150,
#   154,
#   155,
#   156,
#   163,
#   165,
#   166,
#   174,
#   175,
#   178],
#  [2,
#   8,
#   22,
#   25,
#   30,
#   37,
#   41,
#   42,
#   47,
#   48,
#   50,
#   52,
#   68,
#   69,
#   70,
#   71,
#   76,
#   77,
#   80,
#   81,
#   82,
#   84,
#   87,
#   88,
#   89,
#   100,
#   101,
#   104,
#   108,
#   112,
#   113,
#   115,
#   116,
#   117,
#   121,
#   123,
#   124,
#   131,
#   135,
#   141,
#   148,
#   151,
#   152,
#   158,
#   159,
#   161,
#   163,
#   170,
#   172,
#   176,
#   179]]

# %%
from scipy.spatial import distance
euclidean = []

for a in range(0,len(X)):
    temp = []
    for b in range(0,len(X)):
        temp.append((distance.euclidean(X[a],X[b]),b))
    euclidean.append(temp)
euclidean[0]
# len(euclidean[0])
# len([1 for i in euclidean[0] if i<7])
# Out:
# [(0.0, 0),
#  (14.90086987622757, 1),
#  (13.759751051084251, 2),
#  (10.294273140260621, 3),
#  (9.59231261876937, 4),
#  (9.496235850842337, 5),
#  (9.129595020025628, 6),
#  (7.393824860103389, 7),
#  (11.097625608457793, 8),
#  (7.077893798409923, 9),
#  (6.581334825178597, 10),
#  (7.05876944874661, 11),
#  (7.114361242993312, 12),
#  (14.442655321135081, 13),
#  (7.010662084847729, 14),
#  (11.444335710381324, 15),
#  (5.8946485267084805, 16),
#  (11.509208853332058, 17),
#  (7.150735517801208, 18),
#  (7.596551727948713, 19),
#  (8.108901553705284, 20),
#  (11.302278301345229, 21),
#  (7.812145404439279, 22),
#  (6.785105996697571, 23),
#  (7.034360579091404, 24),
#  (8.009077822498716, 25),
#  (7.417230959677575, 26),
#  (6.9968345851771, 27),
#  (8.533588151068598, 28),
#  (6.547141129991018, 29),
#  (12.380403823787823, 30),
#  (7.808157240219082, 31),
#  (7.76570377601745, 32),
#  (9.609187425727663, 33),
#  (14.155657229371872, 34),
#  (8.869553401833596, 35),
#  (7.968024547182827, 36),
#  (7.684798814561039, 37),
#  (8.003496761619614, 38),
#  (10.106286319493396, 39),
#  (13.220455875891663, 40),
#  (9.179981243525717, 41),
#  (10.846363496928202, 42),
#  (13.110982354302529, 43),
#  (7.727753538656562, 44),
#  (10.068514729081244, 45),
#  (7.097999813519201, 46),
#  (9.385457347441776, 47),
#  (8.087552097909278, 48),
#  (10.432177584683652, 49),
#  (8.591125926362988, 50),
#  (7.596546235017449, 51),
#  (10.263650085396643, 52),
#  (8.46538805648286, 53),
#  (8.39399425775373, 54),
#  (7.43836806950842, 55),
#  (7.6877989868740775, 56),
#  (10.926616587884853, 57),
#  (14.3944371162885, 58),
#  (7.250356538389681, 59),
#  (6.779017955035428, 60),
#  (8.97820370551053, 61),
#  (16.658571988369328, 62),
#  (10.340168533750466, 63),
#  (8.756399359298573, 64),
#  (7.860470346350682, 65),
#  (7.368522710100741, 66),
#  (7.376924654363823, 67),
#  (9.32346676601586, 68),
#  (8.956426329339264, 69),
#  (7.47223500344971, 70),
#  (7.881646251576641, 71),
#  (8.593114509480499, 72),
#  (7.589763896958068, 73),
#  (9.87274338580473, 74),
#  (9.5241964737284, 75),
#  (8.03092485909487, 76),
#  (7.433740384181638, 77),
#  (9.419240368394938, 78),
#  (7.4900132830718285, 79),
#  (7.594892960811566, 80),
#  (8.884068010219291, 81),
#  (7.01252127722618, 82),
#  (9.873442807736394, 83),
#  (7.335612245256102, 84),
#  (13.390741300624954, 85),
#  (8.38295918146981, 86),
#  (8.501090220347704, 87),
#  (8.016926453467233, 88),
#  (10.73605393266504, 89),
#  (8.911450903847204, 90),
#  (11.564168761034377, 91),
#  (7.627696557968492, 92),
#  (8.960869058883972, 93),
#  (7.748410077393428, 94),
#  (10.52973668356268, 95),
#  (13.390511999221511, 96),
#  (10.24846864565253, 97),
#  (9.016368685923139, 98),
#  (9.132965218129035, 99),
#  (12.056692679250881, 100),
#  (7.965072487300516, 101),
#  (7.963489244674631, 102),
#  (6.9795025833609845, 103),
#  (7.495412977919523, 104),
#  (11.191774179837655, 105),
#  (7.8348388341917685, 106),
#  (7.424529002857014, 107),
#  (8.374781009976777, 108),
#  (7.47091252333686, 109),
#  (14.763453262563187, 110),
#  (8.86142457519087, 111),
#  (10.606295171436516, 112),
#  (7.984578745932186, 113),
#  (8.177432214718435, 114),
#  (9.403162215774895, 115),
#  (6.688823223063698, 116),
#  (7.918810219756954, 117),
#  (7.521893412247552, 118),
#  (10.039610528392181, 119),
#  (10.33748526972631, 120),
#  (12.616620044136729, 121),
#  (14.675284956062521, 122),
#  (7.772020787061486, 123),
#  (11.561264466943348, 124),
#  (7.941318176590551, 125),
#  (8.775075365806362, 126),
#  (7.6135228044754095, 127),
#  (9.782404687133186, 128),
#  (7.473527792187559, 129),
#  (13.968103434399612, 130),
#  (9.033568747836537, 131),
#  (8.203501232033014, 132),
#  (8.042935127698891, 133),
#  (8.535407100437762, 134),
#  (7.078313461359152, 135),
#  (10.122183760887697, 136),
#  (6.824735075627187, 137),
#  (9.4544530376806, 138),
#  (8.024588155341878, 139),
#  (7.388382125558078, 140),
#  (13.516486612644067, 141),
#  (7.9765982639863635, 142),
#  (7.770693907926719, 143),
#  (7.414443952125263, 144),
#  (7.740454684684898, 145),
#  (7.019787879582866, 146),
#  (8.70951799526486, 147),
#  (8.70034195541309, 148),
#  (6.54857306072406, 149),
#  (7.716602571567521, 150),
#  (8.091584178306244, 151),
#  (8.294999024566511, 152),
#  (9.982597349123873, 153),
#  (8.972801298640293, 154),
#  (8.038373262098222, 155),
#  (7.976545805608998, 156),
#  (13.216459972588163, 157),
#  (11.984211163180895, 158),
#  (9.409934358757408, 159),
#  (7.753873445729528, 160),
#  (7.1610835053782775, 161),
#  (7.839893761919783, 162),
#  (8.088267069029131, 163),
#  (7.802300252224653, 164),
#  (8.126304044866565, 165),
#  (7.9307753439527024, 166),
#  (9.650930741128745, 167),
#  (11.833445185363853, 168),
#  (7.484582558960117, 169),
#  (9.114793012939813, 170),
#  (8.09196516369357, 171),
#  (7.901819643686603, 172),
#  (7.779798959724071, 173),
#  (7.562374120669098, 174),
#  (7.836334677396331, 175),
#  (7.576484516015839, 176),
#  (7.758998099766898, 177),
#  (8.066913961769583, 178),
#  (7.902190611949396, 179)]

# %%
for i in range(0,len(euclidean)):
    euclidean[i].sort()
euclidean[0]

sim_docs = []
for i in range(0,len(euclidean)):
    temp = []
    for j in range(0,len(euclidean)):
        if i==euclidean[i][j][1] :
            continue
        elif len(temp)==5 :
            break
        else:
            temp.append(euclidean[i][j][1])
    sim_docs.append(temp)
sim_docs
# Out:
# [[16, 29, 149, 10, 116],
#  [98, 93, 74, 3, 120],
#  [169, 65, 101, 88, 131],
#  [76, 106, 170, 81, 84],
#  [106, 46, 76, 67, 5],
#  [101, 98, 88, 68, 46],
#  [139, 177, 20, 44, 173],
#  [175, 14, 144, 26, 133],
#  [149, 107, 151, 123, 101],
#  [11, 29, 14, 174, 26],
#  [29, 11, 9, 144, 14],
#  [9, 29, 174, 145, 10],
#  [103, 16, 20, 161, 59],
#  [147, 167, 93, 148, 50],
#  [174, 26, 9, 175, 79],
#  [52, 25, 148, 69, 22],
#  [24, 46, 140, 162, 67],
#  [95, 0, 72, 32, 82],
#  [27, 123, 29, 137, 11],
#  [109, 66, 92, 129, 146],
#  [46, 37, 80, 84, 79],
#  [19, 127, 154, 109, 146],
#  [163, 178, 156, 125, 143],
#  [70, 123, 137, 31, 29],
#  [140, 174, 162, 66, 77],
#  [135, 178, 108, 143, 163],
#  [14, 9, 109, 11, 66],
#  [11, 29, 9, 10, 14],
#  [148, 70, 123, 23, 25],
#  [11, 10, 9, 174, 137],
#  [52, 15, 69, 5, 123],
#  [94, 86, 37, 20, 103],
#  [160, 129, 145, 65, 165],
#  [46, 127, 156, 60, 111],
#  [105, 50, 152, 59, 23],
#  [25, 60, 145, 82, 118],
#  [44, 51, 80, 16, 92],
#  [79, 56, 82, 152, 176],
#  [26, 27, 7, 164, 125],
#  [64, 63, 44, 98, 74],
#  [147, 167, 80, 176, 152],
#  [82, 88, 46, 179, 135],
#  [91, 81, 82, 89, 170],
#  [20, 37, 79, 147, 107],
#  [48, 36, 56, 140, 16],
#  [113, 37, 149, 139, 160],
#  [118, 140, 117, 149, 16],
#  [37, 82, 170, 50, 149],
#  [44, 37, 29, 79, 140],
#  [138, 132, 116, 114, 128],
#  [152, 37, 94, 84, 179],
#  [53, 55, 73, 66, 59],
#  [15, 25, 148, 172, 101],
#  [59, 73, 51, 66, 26],
#  [27, 127, 18, 14, 154],
#  [27, 51, 29, 92, 66],
#  [67, 140, 174, 162, 145],
#  [98, 120, 78, 93, 74],
#  [0, 20, 12, 33, 36],
#  [53, 26, 51, 73, 150],
#  [135, 143, 67, 56, 145],
#  [73, 154, 53, 51, 90],
#  [68, 32, 129, 139, 95],
#  [64, 39, 74, 98, 93],
#  [39, 63, 93, 98, 48],
#  [169, 160, 151, 165, 145],
#  [109, 24, 92, 26, 117],
#  [140, 155, 174, 145, 106],
#  [84, 179, 152, 82, 176],
#  [25, 22, 24, 108, 135],
#  [137, 29, 164, 23, 123],
#  [60, 135, 111, 108, 25],
#  [32, 10, 108, 7, 82],
#  [53, 51, 86, 59, 92],
#  [93, 78, 98, 63, 64],
#  [177, 46, 120, 98, 149],
#  [106, 82, 67, 179, 145],
#  [174, 140, 162, 155, 166],
#  [98, 74, 93, 120, 5],
#  [14, 135, 125, 104, 166],
#  [84, 152, 92, 106, 117],
#  [170, 179, 152, 82, 76],
#  [106, 76, 179, 67, 84],
#  [114, 132, 138, 86, 31],
#  [106, 152, 67, 82, 76],
#  [170, 56, 113, 116, 41],
#  [94, 73, 31, 92, 103],
#  [22, 25, 156, 163, 104],
#  [125, 77, 22, 179, 79],
#  [81, 170, 84, 82, 112],
#  [53, 59, 86, 73, 51],
#  [81, 170, 76, 82, 106],
#  [66, 24, 109, 174, 106],
#  [74, 98, 64, 78, 56],
#  [31, 86, 50, 152, 37],
#  [32, 129, 139, 160, 60],
#  [73, 177, 84, 53, 50],
#  [56, 113, 126, 82, 37],
#  [78, 93, 74, 176, 5],
#  [131, 137, 70, 102, 18],
#  [93, 78, 98, 57, 74],
#  [88, 77, 172, 175, 179],
#  [133, 144, 7, 137, 9],
#  [117, 16, 46, 118, 12],
#  [142, 174, 140, 145, 162],
#  [82, 76, 60, 126, 147],
#  [76, 67, 82, 140, 145],
#  [149, 79, 175, 135, 127],
#  [25, 176, 135, 125, 10],
#  [155, 174, 66, 166, 140],
#  [128, 168, 141, 68, 139],
#  [127, 143, 108, 154, 178],
#  [84, 82, 159, 76, 106],
#  [172, 151, 56, 160, 60],
#  [132, 92, 55, 138, 66],
#  [87, 161, 25, 156, 163],
#  [135, 16, 56, 179, 140],
#  [66, 140, 104, 162, 106],
#  [46, 142, 145, 140, 149],
#  [171, 51, 55, 59, 38],
#  [98, 57, 78, 74, 64],
#  [148, 94, 81, 152, 50],
#  [99, 134, 136, 164, 70],
#  [11, 135, 179, 70, 18],
#  [22, 163, 35, 136, 171],
#  [79, 14, 175, 77, 88],
#  [92, 146, 53, 66, 55],
#  [156, 143, 178, 163, 60],
#  [139, 18, 123, 32, 160],
#  [160, 169, 165, 32, 145],
#  [103, 36, 97, 4, 46],
#  [146, 137, 7, 133, 102],
#  [114, 138, 66, 117, 24],
#  [144, 102, 9, 11, 29],
#  [137, 164, 38, 144, 27],
#  [104, 77, 142, 166, 179],
#  [111, 127, 154, 22, 156],
#  [144, 29, 9, 133, 10],
#  [132, 114, 66, 92, 153],
#  [129, 32, 14, 56, 26],
#  [162, 155, 174, 142, 24],
#  [168, 68, 139, 177, 173],
#  [174, 155, 143, 145, 166],
#  [142, 145, 166, 178, 174],
#  [133, 137, 7, 9, 10],
#  [142, 165, 174, 143, 155],
#  [27, 137, 164, 14, 92],
#  [152, 80, 37, 176, 84],
#  [123, 71, 179, 135, 113],
#  [46, 16, 118, 29, 135],
#  [144, 27, 10, 26, 11],
#  [172, 160, 65, 142, 169],
#  [179, 106, 67, 140, 162],
#  [138, 146, 70, 132, 92],
#  [111, 127, 178, 143, 150],
#  [174, 142, 140, 162, 145],
#  [178, 127, 143, 163, 142],
#  [118, 20, 46, 103, 153],
#  [123, 126, 101, 148, 88],
#  [84, 80, 82, 50, 152],
#  [151, 65, 165, 145, 169],
#  [16, 118, 151, 149, 46],
#  [140, 174, 155, 142, 166],
#  [178, 143, 166, 165, 156],
#  [137, 175, 27, 144, 10],
#  [145, 143, 142, 174, 166],
#  [174, 143, 142, 155, 162],
#  [94, 84, 152, 50, 80],
#  [141, 68, 139, 177, 173],
#  [65, 151, 165, 160, 77],
#  [81, 179, 76, 82, 163],
#  [60, 87, 14, 32, 104],
#  [151, 179, 142, 135, 77],
#  [177, 160, 129, 176, 104],
#  [155, 142, 162, 166, 77],
#  [7, 14, 174, 155, 142],
#  [77, 145, 67, 174, 175],
#  [173, 129, 160, 135, 106],
#  [143, 163, 156, 142, 166],
#  [135, 77, 142, 104, 140]]

# %%
# testing
test
